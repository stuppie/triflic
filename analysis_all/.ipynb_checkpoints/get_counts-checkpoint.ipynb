# %%
import sys
sys.path.insert(0, "/home/gstupp/projects/metaproteomics")

# %%
import os
import requests
import pandas as pd
from tqdm import tqdm
from collections import defaultdict, Counter
from glob import glob
import numpy as np
from itertools import chain
import matplotlib
matplotlib.rcParams.update({'font.size': 22})

# %%
from metaproteomics.file_processing.blazmass_tools import dta_select_parser, build_pep_quant_dict
from metaproteomics.goatools import obo_parser
goa = obo_parser.GODag()
# Out:
# load obo file /home/gstupp/projects/metaproteomics/metaproteomics/goatools/go-basic.obo
# 48437 nodes imported

# %%
files = glob("data/*/*/*.txt")

# %%
files
# Out:
# ['data/PA/Triflic/PA triflic 4.txt',
#  'data/PA/Triflic/PA triflic 3.txt',
#  'data/PA/Triflic/PA triflic 5.txt',
#  'data/PA/pellet triflic/PA pellet triflic 2.txt',
#  'data/PA/pellet triflic/PA pellet triflic 4.txt',
#  'data/PA/pellet triflic/PA pellet triflic 3.txt',
#  'data/PA/Sonic/PA sonic 1.txt',
#  'data/PA/Sonic/PA sonic 3.txt',
#  'data/PA/Sonic/PA sonic 4.txt',
#  'data/Jurkat/Triflic/Jurkat triflic 1.txt',
#  'data/Jurkat/Triflic/Jurkat triflic test.txt',
#  'data/Jurkat/Triflic/Jurkat triflic 2.txt',
#  'data/Jurkat/Sonic/Jurkat sonic 7.txt',
#  'data/Jurkat/Sonic/Jurkat sonic 1.txt',
#  'data/Jurkat/Sonic/Jurkat sonic 8.txt',
#  'data/BS/Triflic/BS triflic 3.txt',
#  'data/BS/Triflic/BS triflic 1.txt',
#  'data/BS/Triflic/BS triflic 2.txt',
#  'data/BS/Sonic/BS sonic 3.txt',
#  'data/BS/Sonic/BS sonic 4.txt',
#  'data/BS/Sonic/BS sonic 2.txt']

# %%
df = pd.read_csv("annotations.mapped.gaf", sep="\t", comment="!", header=None)
df = df.rename(columns={1:"id", 4:"go_id", 8:'aspect'})
#df = df.query("go_id != 'GO:0005575'")  # remove 'cellular component'
df.head(2)
# Out:
#            0          id              2    3       go_id               5    6  \
# 0  UniProtKB  A0A024R161  DNAJC25-GNG10  NaN  GO:0071944  GO_REF:0000002  IEA
# 1  UniProtKB  A0A024R161  DNAJC25-GNG10  NaN  GO:0016020  GO_REF:0000002  IEA
#
#                                        7 aspect  \
# 0  InterPro:IPR001770|InterPro:IPR015898      C
# 1  InterPro:IPR001770|InterPro:IPR015898      C
#
#                                                   9  \
# 0  Guanine nucleotide-binding protein subunit gamma
# 1  Guanine nucleotide-binding protein subunit gamma
#
#                              10       11          12        13        14   15  \
# 0  A0A024R161_HUMAN|hCG_1994888  protein  taxon:9606  20170603  InterPro  NaN
# 1  A0A024R161_HUMAN|hCG_1994888  protein  taxon:9606  20170603  InterPro  NaN
#
#     16
# 0  NaN
# 1  NaN

# %%
# sanity check, show all annotations
print(', '.join({goa[x].name: x for x in set(df['go_id'])}))
# Out:
# cytoplasm, cellular_component, cell, cell periphery, membrane, organelle

# %%
gb = df.groupby("id").agg({'go_id': lambda x: ','.join(x)})
annots = {k:v.split(",") for k,v in dict(zip(gb.index,gb.go_id)).items()}

# %%
len(annots)
# Out:
# 23385

# %%
def get_proteins(loci):
    loci = [x for x in loci['loci'] if "|" in x['description']]
    for locus in loci:
        locus['uniprot'] = locus['description'].split("|")[1]
    return loci
locus = next(dta_select_parser(files[9], return_reverse=False))
get_proteins(locus)
# Out:
# [{'Descriptive Name': 'Tubulin alpha-1B chain (Fragment) OS=Homo sapiens GN=TUBA1B PE=1 SV=1 ',
#   'EMPAI': 4.5847015,
#   'Length': 75,
#   'Locus': 0,
#   'MolWt': 8288,
#   'NSAF': 0.0036975294,
#   'Sequence Count': 4,
#   'Sequence Coverage': 0.747,
#   'Spectrum Count': 9,
#   'Validation Status': 'U',
#   'description': 'tr|F8VX09|F8VX09_HUMAN',
#   'pI': 5.3,
#   'reverse': False,
#   'uniprot': 'F8VX09'}]

# %%
def get_go_count(file):
    """
    If a locus has multiple proteins, the go annotations for each protein are used and the spectral count assigned
    is divided by the number of proteins in the locus.
    If a protein has multiple go terms, the spectral count for that protein is divided by the number of GO terms
    """
    descr = dict()
    d = defaultdict(int)
    for locus in dta_select_parser(file, return_reverse=False):
        proteins = get_proteins(locus)
        for p in proteins:
            this_go = annots.get(p['uniprot'], [])
            descr[p['uniprot']] = {'go': ";".join(this_go), 'q': locus['quantification'], 
                          'go_name': ";".join([goa[x].name for x in this_go]), 
                          'name': p['Descriptive Name']}
            for go in this_go:
                c = (locus['quantification']/len(proteins))/len(this_go)
                d[go]+=c
            if not this_go:
                d['unknown']+=locus['quantification']/len(proteins)
    d = dict(d)
    return d, descr

d,p = get_go_count(files[12])
d
# Out:
# {'GO:0005575': 2888.49693939993,
#  'GO:0005623': 4159.516937978808,
#  'GO:0005737': 6437.163632350221,
#  'GO:0016020': 1891.4786544661602,
#  'GO:0043226': 6964.430864602792,
#  'GO:0071944': 1290.7056479696607,
#  'unknown': 19077.20732323235}

# %%
def get_membrane_count(d):
    # cell periphery and membrane == membrane
    membrane = {'GO:0071944', 'GO:0016020'}
    membrane_count = sum(count for go,count in d.items() if go in membrane)
    not_membrane_count = sum(count for go,count in d.items() if go not in membrane and go!="unknown")
    return membrane_count, not_membrane_count

# %%
counts = dict()
all_counts = dict()
for file in tqdm(files):
    d,p = get_go_count(file)
    all_counts[file] = {goa[k].name if k!="unknown" else "unknown":v for k,v in d.items()}
    membrane_count, not_membrane_count = get_membrane_count(d)
    counts[file] = (membrane_count, not_membrane_count, np.log(membrane_count/not_membrane_count))
    pd.DataFrame(p).T.to_csv(file + "_go_counts.csv")
# Out:
# 100%|██████████| 21/21 [00:04<00:00,  5.12it/s]

# %%
df_out = pd.DataFrame({'files': list(counts.keys()),
 'membrane': [x[0] for x in counts.values()],
 'non-membrane': [x[1] for x in counts.values()],
 'ratio': [x[2] for x in counts.values()],
 'method': ["sonic" if "sonic" in file else "tri" for file in counts],
 'pellet': ["pellet" in file for file in counts],
 'cell': [file.split("/")[1] for file in counts]})
df_out = df_out.sort_values(["cell", "method"])
df_out
# Out:
#       cell                                           files      membrane  \
# 0       BS                    data/BS/Sonic/BS sonic 2.txt   2147.900502
# 1       BS                    data/BS/Sonic/BS sonic 3.txt   1810.113983
# 11      BS                    data/BS/Sonic/BS sonic 4.txt   1938.027914
# 5       BS                data/BS/Triflic/BS triflic 1.txt   1582.936852
# 9       BS                data/BS/Triflic/BS triflic 3.txt   2918.966170
# 12      BS                data/BS/Triflic/BS triflic 2.txt   2440.764763
# 3   Jurkat            data/Jurkat/Sonic/Jurkat sonic 8.txt   2297.343065
# 7   Jurkat            data/Jurkat/Sonic/Jurkat sonic 1.txt   2609.509022
# 14  Jurkat            data/Jurkat/Sonic/Jurkat sonic 7.txt   3182.184302
# 16  Jurkat     data/Jurkat/Triflic/Jurkat triflic test.txt    772.366179
# 18  Jurkat        data/Jurkat/Triflic/Jurkat triflic 2.txt    525.212922
# 20  Jurkat        data/Jurkat/Triflic/Jurkat triflic 1.txt    494.086119
# 10      PA                    data/PA/Sonic/PA sonic 3.txt   1276.448637
# 15      PA                    data/PA/Sonic/PA sonic 4.txt    848.705370
# 17      PA                    data/PA/Sonic/PA sonic 1.txt   1613.926800
# 2       PA                data/PA/Triflic/PA triflic 3.txt   4404.314902
# 4       PA                data/PA/Triflic/PA triflic 5.txt   4056.952206
# 6       PA  data/PA/pellet triflic/PA pellet triflic 3.txt  11023.757049
# 8       PA  data/PA/pellet triflic/PA pellet triflic 2.txt  13515.862426
# 13      PA                data/PA/Triflic/PA triflic 4.txt   3729.714966
# 19      PA  data/PA/pellet triflic/PA pellet triflic 4.txt   9812.565808
#
#    method  non-membrane pellet     ratio
# 0   sonic  15042.099498  False -1.946362
# 1   sonic  13497.886017  False -2.009143
# 11  sonic  13957.972086  False -1.974380
# 5     tri  11859.063148  False -2.013811
# 9     tri  24296.033830  False -2.119084
# 12    tri  20389.235237  False -2.122696
# 3   sonic  19091.923058  False -2.117512
# 7   sonic  17737.063597  False -1.916494
# 14  sonic  20449.608374  False -1.860396
# 16    tri   7299.670283  False -2.246126
# 18    tri   4393.911284  False -2.124171
# 20    tri   4267.349490  False -2.156038
# 10  sonic  17116.551363  False -2.595964
# 15  sonic  11826.294630  False -2.634369
# 17  sonic  20090.073200  False -2.521556
# 2     tri  12535.685098  False -1.045995
# 4     tri  13015.047794  False -1.165674
# 6     tri  10108.242951   True  0.086701
# 8     tri  12789.137574   True  0.055268
# 13    tri  12304.285034  False -1.193616
# 19    tri  10127.434192   True -0.031584

# %%
df_out.to_csv("df_out.csv")

# %%
# %matplotlib inline
# Out:
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import seaborn as sns
sns.set(font_scale=2)
g = sns.factorplot(x="cell", y="ratio", hue="method", data=df_out.query("not pellet"), kind="box")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(10, 6)

# %%
all_counts = pd.DataFrame(all_counts)

# %%
all_counts = all_counts.T
all_counts.index = all_counts.index.map(lambda x:x.split("/")[-1].split(".")[0])
all_counts.to_csv("all_counts.csv")
all_counts
# Out:
#                             cell  cell periphery  cellular_component  \
# BS sonic 2           3055.747550      739.478580          648.521284
# BS sonic 3           3265.455680      620.313592          524.639472
# BS sonic 4           2740.860409      655.989832          676.496631
# BS triflic 1         1839.329765      593.586050          391.679482
# BS triflic 2         3136.300555      880.134676          704.882295
# BS triflic 3         4036.621942     1119.679751          847.638994
# Jurkat sonic 1       4774.609898     1024.083085         1066.811191
# Jurkat sonic 7       4159.516938     1290.705648         2888.496939
# Jurkat sonic 8       5257.433035      903.538090         1276.906876
# Jurkat triflic 1     1156.251284      186.885675          192.472227
# Jurkat triflic 2     1201.702421      195.887848          241.744454
# Jurkat triflic test  1939.696244      288.627360          524.230763
# PA sonic 1           5339.837975      507.740213          693.600000
# PA sonic 3           4640.702004      406.931668          506.800000
# PA sonic 4           2586.925033      291.478180          516.241453
# PA triflic 3         2379.624170     1145.964469          305.988889
# PA triflic 4         2447.673374      985.928018          453.541453
# PA triflic 5         2340.716658     1032.188607          424.255556
# PA pellet triflic 2  2895.012360     3365.263600          340.652564
# PA pellet triflic 3  2448.259821     2701.640622          282.061111
# PA pellet triflic 4  2316.345639     2472.547602          347.808974
#
#                         cytoplasm      membrane    organelle       unknown
# BS sonic 2           10917.373629   1408.421923   420.457035   9499.000000
# BS sonic 3            9333.060148   1189.800391   374.730717   8636.000000
# BS sonic 4           10179.250982   1282.038081   361.364064   9077.000000
# BS triflic 1          9014.220291    989.350802   613.833611   6424.000000
# BS triflic 2         15838.645543   1560.630087   709.406843   8810.000000
# BS triflic 3         18211.113955   1799.286419  1200.658938  10981.000000
# Jurkat sonic 1        5028.782847   1585.425937  6866.859661  18792.427381
# Jurkat sonic 7        6437.163632   1891.478654  6964.430865  19077.207323
# Jurkat sonic 8        4838.873687   1393.804975  7718.709460  17101.733877
# Jurkat triflic 1      1301.916983    307.200444  1616.708996   3935.564391
# Jurkat triflic 2      1239.063290    329.325074  1711.401119   4561.875794
# Jurkat triflic test   2027.233400    483.738819  2808.509876   6564.963538
# PA sonic 1           12623.467399   1106.186587  1433.167827  10471.000000
# PA sonic 3           10734.608791    869.516969  1234.440568  10297.000000
# PA sonic 4            7807.838858    557.227189   915.289286   5966.000000
# PA triflic 3          8865.994658   3258.350433   984.077381   6802.000000
# PA triflic 4          8509.850763   2743.786948   893.219444   8657.000000
# PA triflic 5          9240.793987   3024.763599  1009.281593   7062.000000
# PA pellet triflic 2   8561.250397  10150.598826   992.222253   8247.000000
# PA pellet triflic 3   6632.854559   8322.116427   745.067460   6139.000000
# PA pellet triflic 4   6872.859615   7340.018205   590.419963   6833.000000

# %%
ax = all_counts.plot.bar(stacked=True, legend=False)
ax.set_ylabel("spectral counts")
patches, labels = ax.get_legend_handles_labels()
ax.legend(patches[::-1], labels[::-1], bbox_to_anchor=(1.4, 1), fontsize='large')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)

# %%
ax = all_counts.div(all_counts.sum(1), axis=0).plot.bar(stacked=True, legend=False)
ax.set_ylabel("spectral counts")
ax.set_ylim(0,1)
patches, labels = ax.get_legend_handles_labels()
ax.legend(patches[::-1], labels[::-1], bbox_to_anchor=(1.4, 1), fontsize='large')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)
ax.axvline(x=-0.45, linestyle='--', color='k')
ax.axvline(x=5.5, linestyle='--', color='k')
ax.axvline(x=11.5, linestyle='--', color='k')
ax.axvline(x=17.45, linestyle='--', color='k')
ax.axvline(x=2.5, linestyle=':', color='k')
ax.axvline(x=8.5, linestyle=':', color='k')
ax.axvline(x=14.5, linestyle=':', color='k')

# %%
df = all_counts.T
gs = ["BS sonic", "BS triflic", "Jurkat sonic", "Jurkat triflic", "PA sonic", "PA triflic", "PA pellet triflic"]
for g in gs:
    df[g] = df[df.columns[df.columns.str.contains(g)]].sum(1)
df = df[gs]
df3 = df.T

# %%
ax = df3.plot.bar(stacked=True, legend=False)
ax.set_ylabel("spectral counts")
patches, labels = ax.get_legend_handles_labels()
ax.legend(patches[::-1], labels[::-1], bbox_to_anchor=(1.4, 1), fontsize='large')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)
ax.axvline(x=1.5, linestyle='--', color='k')
ax.axvline(x=3.5, linestyle='--', color='k')

# %%
ax = df3.div(df3.sum(1), axis=0).plot.bar(stacked=True, legend=False)
ax.set_ylabel("spectral counts")
ax.set_ylim(0,1)
patches, labels = ax.get_legend_handles_labels()
ax.legend(patches[::-1], labels[::-1], bbox_to_anchor=(1.4, 1), fontsize='large')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(20)
ax.axvline(x=1.5, linestyle='--', color='k')
ax.axvline(x=3.5, linestyle='--', color='k')
